# %% [markdown]
# ## Document Loaders
#
# are components in LangChain used to load data from various sources into a standardized form (usually as Document objects), which can then be used for chunking embedding. retrieval and generation.
#
# Example:
#
# - TextLoader
# - PyPDFLoader
# - WebBaseLoader
# - CSVLoader
#
# ```
# Document (
#     page_content ="The actual text content",
#     metadata = ("source": "filename.pdf", ...)
# )
# ```

# %% [markdown]
# ## TextLoader

# %%
from langchain_community.document_loaders import TextLoader
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate

load_dotenv()

model = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = PromptTemplate.from_template(
    "Write a summary for the following poem \n{poem}"
)

parser = StrOutputParser()

loader = TextLoader('cricket.txt', encoding='utf-8')

docs = loader.load()

chain = prompt | model | parser

result = chain.invoke({"poem": docs[0].page_content})
print(result)
# Out:
# The poem is a tribute to the sport of cricket, describing it as more than just a game, but a way of life. It captures the excitement and intensity of the game, from the roar of the crowd to the skill and strategy of the players. The poem also touches on the dreams and aspirations of young players, who imagine themselves as future legends on makeshift grounds in their neighborhoods. Ultimately, the poem conveys the idea that cricket is a journey of ups and downs, but one that teaches resilience, perseverance, and the ability to rise above adversity, making it a timeless and enduring part of human experience.

# %% [markdown]
# ## PyPDFLoader
#
# is a document loader in LangChain used to load content from PDF files and convert each page into a Document object
# ```
# [
#     Document(page_content = "Text from page 0, metadata={"page": 0, "source": "file.pdf})
#     Document(page_content = "Text from page 1, metadata={"page": 0, "source": "file.pdf})
# ]
# ```
#
# Limitations:
#
# It uses the PyPDF library under the hood - hot great with scanned PDFs or complex layouts

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Aromal_Dileep_CV.pdf")
docs = loader.load()
print(docs)
print(len(docs))
print(docs[1].metadata)
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2026-05-06T08:29:12-07:00', 'author': 'Aromal Dileep', 'moddate': '2026-05-06T08:29:12-07:00', 'source': 'Aromal_Dileep_CV.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Dear Hiring Manager, \n  \nI am excited to apply for opportunities in Machine Learning, AI Engineering, and \nComputer Vision at your organization. \n  \nI am a self taught Machine Learning Engineer with strong hands on experience building \npractical AI systems using Deep Learning, Computer Vision, Semantic Search, and \nGenerative AI. What makes my journey unique is that I entered the field without a \ntraditional technical background and built my skills independently through consistent \nlearning and real world project development. \n  \nOne of my major projects, SmartCart AI, is a production ready multimodal semantic \nsearch system that uses CLIP embeddings and FAISS to perform scalable text  and \nimage 
# ...

# %% [markdown]
# ## DirectoryLoader
#
# is a document loader that lets you load multiple documents from a directory (folder) of files.
#
# ## WebBaseLoader
# ## CSVLoader

# %%
from langchain_community.document_loaders import WebBaseLoader, DirectoryLoader, CSVLoader
