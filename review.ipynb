# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

X = [1,2,3,4,5]
y = [2,4,6,8,10]


X =np.array(X).reshape(-1,1)
y = np.array(y).reshape(-1,1)



X_train, X_test, y_train, y_test = train_test_split(
    X,y,random_state=42, test_size=0.2
)
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)


class LinearNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(1, 10),
            nn.ReLU(),
            nn.Linear(10,14),
            nn.ReLU(),
            nn.Linear(14,1)
        )
    
    def forward(self,x):
        return self.model(x)
    
model = LinearNN()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)


epochs = 1000
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)

    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 100 == 0:
        print(f"Epoch [{epoch +1}/ {epochs}, Loss: {loss.item()}]")
# Out:
# Epoch [100/ 1000, Loss: 0.1525171846151352]
# Epoch [200/ 1000, Loss: 0.008952249772846699]
# Epoch [300/ 1000, Loss: 0.00010159233352169394]
# Epoch [400/ 1000, Loss: 2.105757062054181e-07]
# Epoch [500/ 1000, Loss: 4.9467985263618175e-11]
# Epoch [600/ 1000, Loss: 2.8421709430404007e-13]
# Epoch [700/ 1000, Loss: 1.2789769243681803e-13]
# Epoch [800/ 1000, Loss: 1.2789769243681803e-13]
# Epoch [900/ 1000, Loss: 1.2789769243681803e-13]
# Epoch [1000/ 1000, Loss: 2.4158453015843406e-13]

# %%
model.eval()

with torch.no_grad():
    x_new = torch.tensor([[15.0]])
    prediction = model(x_new)


round(prediction.item())
# Out:
# 30

# %%
s ="were"
set(s)
# Out:
# {'e', 'r', 'w'}

# %%
"lol"
